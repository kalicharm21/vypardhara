# %% [markdown]
# # Entity Resolution End-to-End Demo

# %%
from services.matching_engine.similarity.composite_scorer import score_pair, Record
a = Record('acme industries','12 mg road bangalore 560001','560001',None,None,'labour')
b = Record('acme inds','12 mg rd bangalore 560001','560001',None,None,'factories')
print(score_pair(a, b))
