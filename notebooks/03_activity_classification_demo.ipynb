# %% [markdown]
# # Activity Classification Demo

# %%
from datetime import datetime, timedelta
from services.activity_engine.classifier import classify
ev = lambda t,d: {'ubid':'U','dept':'labour','event_type':t,'occurred_at':(datetime.utcnow()-timedelta(days=d)).isoformat()}
print(classify([ev('livelink_verified',30), ev('gst_return_filed',60)]))
